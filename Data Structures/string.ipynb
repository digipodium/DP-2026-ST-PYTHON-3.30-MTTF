# %%
x = "Beautiful"
y = "Hey"
print(y+x) #string concatenation
# Out:
# HeyBeautiful

# %%
a = "hey"
print(a*5)
# Out:
# heyheyheyheyhey

# %%
x.upper()
# Out:
# 'BEAUTIFUL'

# %%
x.lower()
# Out:
# 'beautiful'

# %%
x.capitalize()
# Out:
# 'Beautiful'

# %%
a = "all is well"
a.title()
# Out:
# 'All Is Well'

# %%
poem = '''Johny Johny yes papa
easting sugar no papa
telling a lie no papa
open your mouth hahaha'''
print(poem)
# Out:
# Johny Johny yes papa
# easting sugar no papa
# telling a lie no papa
# open your mouth hahaha

# %%
poem.find('papa')
# Out:
# 16

# %%
p = poem.replace("papa","fufa").replace("sugar","poison").replace(
    "easting","drinking"
)
print(p)
# Out:
# Johny Johny yes fufa
# drinking poison no fufa
# telling a lie no fufa
# open your mouth hahaha

# %%
a.split()
# Out:
# ['all', 'is', 'well']

# %%
p.splitlines()
# Out:
# ['Johny Johny yes fufa',
#  'drinking poison no fufa',
#  'telling a lie no fufa',
#  'open your mouth hahaha']

# %%
text = " hello "
text.strip() #removes whitespace
# Out:
# 'hello'

# %%
a.count('l')
# Out:
# 4

# %%
a.startswith('a')
# Out:
# True

# %%
a.endswith("l")
# Out:
# True

# %%
"hello".isalpha()
# Out:
# True

# %%
"123".isdigit()
# Out:
# True

# %%
"hello123".isalnum()
# Out:
# True

# %%
"Hello World".swapcase()
# Out:
# 'hELLO wORLD'

# %%
len(a)
# Out:
# 11

# %%
"hello".index('l')
# Out:
# 2

# %%
"V".isdigit()
# Out:
# False

# %%
"V".isnumeric()
# Out:
# False
