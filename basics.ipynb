# %% [markdown]
# Welcome to my notebook

# %% [markdown]
# # Heading
# ### Heading2
# ###### Heading3

# %% [markdown]
# `Highlighted text`
# - point1
#     - subpoint
#     - subpoint1
#         - sub subpoint
#     - subpoint 2
# - point2
# - point3

# %%
a = 10
print(a)
# Out:
# 10

# %%
a = 10
b = 20
print(a+b)
print(a-b)
print(a*b)
print(a/b) #3.333
print(a%b) #1
print(a//b) #3
print(a**b)
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 0
# 100000000000000000000

# %%
x = 10
x+=5
print(x)
# Out:
# 15

# %%
x-=2
print(x)
# Out:
# 13

# %%
x*=2
print(x)
# Out:
# 26

# %%
x = 10
y = 12
z = 15
x<y and x>z
# Out:
# False

# %%
x = 10
y = 12
z = 15
x<y or x>z
# Out:
# True

# %%
x = 10
y = 10
z = 15
not(x<y and x>z)
# Out:
# True

# %%
x is y
# Out:
# True

# %%
mail = 'shakeelareeba02@gmail.com'
'@.' in mail
# Out:
# False

# %%
poem = '''Johny Johny yes papa
eating sugar no papa
telling a lie no papa
open your mouth hahahaha'''
print(poem)
# Out:
# Johny Johny yes papa
# eating sugar no papa
# telling a lie no papa
# open your mouth hahahaha

# %%
type(x)
# Out:
# int

# %% [markdown]
# `Type Casting` - is a process of converting one data type into another data type

# %%
a = 10
x = str(a)
b = "Hello"
print(x+b) #string concatenation
# Out:
# 10Hello

# %%
x = int(input("Enter a number"))
y = int(input("Enter second number"))
print(x+y)
# Out:
# 30

# %%
x = 10
y = 20
print("sum is:",x+y)
print("sum of",x,"and",y,"is",x+y)
print(f"sum of {x} and {y} is {x+y}")
# Out:
# sum is: 30
# sum of 10 and 20 is 30
# sum of 10 and 20 is 30
